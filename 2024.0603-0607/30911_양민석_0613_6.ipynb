# %% [markdown]
# # 30911_양민석_0613_6

# %%
# 라이브러리 불러오기 및 별명 지정하기
import matplotlib.pyplot as plt
# 한글폰트 적용하기
plt.rc('font', family = 'Malgun Gothic')

# data
sales = [1,5,7,3,7]
month = [3,4,5,6,7]

# 막대 그래프 그리기 plt.bar()
plt.title('월별 판매 실적') # 제목
plt.bar(month, sales, color = 'b') # 컬러 파랑

plt.show()

# %%
# 라이브러리 불러오기 및 별명 지정하기
import matplotlib.pyplot as plt
# 한글폰트 적용하기
plt.rc('font', family = 'Malgun Gothic')

# data
sales = [1,5,7,3,7]
month = [3,4,5,6,7]

# 제목
plt.title('월별 판매 실적')

# 가로 바차트 그리기 barh
plt.barh(month, sales, color = 'red')
plt.show()

# %%
# 라이브러리 불러오기 및 별명 지정하기
import matplotlib.pyplot as plt
# 한글폰트 적용하기
plt.rc('font', family = 'Malgun Gothic')

# data
sales = [1,5,7,3,7]
month = [3,4,5,6,7]

# 제목
plt.title('월별 판매 실적')

# 가로 바차트 그리기 barh(range)
plt.barh(range(3,8), sales, color = 'red')
plt.show()

# %% [markdown]
# # 히스토그램 그리기

# %%
sales = [1,5,7,3,7]

plt.hist(sales)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

a = []
for i in range(10):
    a.append(random.randint(1,10))
print(a)

plt.hist(a)
plt.show()
# Out:
# [7, 7, 6, 5, 10, 2, 4, 9, 2, 6]
